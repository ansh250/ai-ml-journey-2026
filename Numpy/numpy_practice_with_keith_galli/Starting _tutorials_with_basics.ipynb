# %%
import numpy as np

# %%
# creating arrays
a = np.array([1,2,3],dtype="int32")
print(a)        # we can change the dtype of array by giving above command
a
# Out:
# [1 2 3]
# array([1, 2, 3], dtype=int32)

# %%
# for 2d arrays
b = np.array([[8.0,9.0,5.0],[5,6,7]])   # for creating nD arrays put a list inside a list
print(b)
# Out:
# [[8. 9. 5.]
#  [5. 6. 7.]]

# %%
# Get Dimension
a.ndim
# Out:
# 1

# %%
b.ndim
# Out:
# 2

# %%
# Get shape
a.shape
# Out:
# (3,)

# %%
b.shape
# Out:
# (2, 3)

# %%
# Get type
a.dtype
# Out:
# dtype('int32')

# %%
b.dtype
# Out:
# dtype('float64')

# %%
# Get size
a.itemsize
# Out:
# 4

# %%
b.itemsize
# Out:
# 8

# %%
#Get total size
a.nbytes
# Out:
# 12

# %%
b.nbytes
# Out:
# 48

# %%
# Get total items
a.size
# Out:
# 3

# %%
b.size
# Out:
# 6
